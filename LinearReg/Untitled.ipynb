# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
bias= 100
x,y,coef=make_regression(n_features=1,noise=10,bias=bias,random_state=42, coef=True)

# %%
x.shape,y.shape
# Out:
# ((100, 1), (100,))

# %%
plt.scatter(x,y)

# %%
coef
# Out:
# array(41.74110031)

# %%
bias
# Out:
# 100

# %%
#coef and bias is given by sklearn 
y_gen = x * coef + bias

# %%
plt.scatter(x,y)
plt.plot(y_gen)
